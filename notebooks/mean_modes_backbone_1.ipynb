# %%
import matplotlib.pyplot as plt
import numpy as np
from enmspring.graphs_bigtraj import BackboneMeanModeAgent
from enmspring.abbr import Abbreviation

rootfolder = '/home/ytcdata/bigtraj_fluctmatch/500ns'

# %% [markdown]
# ### Part 1: Batch Make DataFrame

# %%
hosts = ['a_tract_21mer', 'g_tract_21mer', 'atat_21mer', 'gcgc_21mer']
interval_time = 500
make_and_save = True
for host in hosts:
    s_agent = BackboneMeanModeAgent(host, rootfolder, interval_time)
    if make_and_save:
        s_agent.preprocess_all_small_agents()
        s_agent.make_mean_mode_laplacian()
        s_agent.save_mean_mode_laplacian_into_npy()
        s_agent.make_mean_mode_std_laplacian()
        s_agent.save_mean_mode_std_laplacian_into_npy()
        s_agent.make_b0_mean_std()
        s_agent.save_b0_mean_std_into_npy()
# Out:
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2250_2750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2500_3000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2750_3250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3000_3500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3250_3750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3500_4000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3750_4250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4000_4500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4250_4750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4500_5000/pd_dfs exists
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Set laplacian_mat.
# Save laplacian_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/laplacian_backbone.npy
# Save laplacian_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/laplacian_backbone.std.npy
# Save b0_mean_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/b0_backbone.mean.npy
# Save b0_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/b0_backbone.std.npy
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/2250_2750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/2500_3000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/2750_3250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/3000_3500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/3250_3750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/3500_4000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/3750_4250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/4000_4500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/4250_4750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/bdna+bdna/4500_5000/pd_dfs exists
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 459 eigenvectors belonging to STRAND1.
# There are 396 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Set laplacian_mat.
# Save laplacian_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/mean_mode_npy/laplacian_backbone.npy
# Save laplacian_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/mean_mode_npy/laplacian_backbone.std.npy
# Save b0_mean_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/mean_mode_npy/b0_backbone.mean.npy
# Save b0_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/g_tract_21mer/mean_mode_npy/b0_backbone.std.npy
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2250_2750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2500_3000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2750_3250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/3000_3500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/3250_3750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/3500_4000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/3750_4250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/4000_4500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/4250_4750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/4500_5000/pd_dfs exists
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 428 eigenvectors belonging to STRAND1.
# There are 427 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Set laplacian_mat.
# Save laplacian_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/mean_mode_npy/laplacian_backbone.npy
# Save laplacian_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/mean_mode_npy/laplacian_backbone.std.npy
# Save b0_mean_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/mean_mode_npy/b0_backbone.mean.npy
# Save b0_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/mean_mode_npy/b0_backbone.std.npy
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/2250_2750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/2500_3000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/2750_3250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/3000_3500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/3250_3750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/3500_4000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/3750_4250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/4000_4500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/4250_4750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/bdna+bdna/4500_5000/pd_dfs exists
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 429 eigenvectors belonging to STRAND1.
# There are 426 eigenvectors belonging to STRAND2.
# Sum of two strands: 855
# Set laplacian_mat.
# Save laplacian_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/mean_mode_npy/laplacian_backbone.npy
# Save laplacian_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/mean_mode_npy/laplacian_backbone.std.npy
# Save b0_mean_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/mean_mode_npy/b0_backbone.mean.npy
# Save b0_std_mat into /home/ytcdata/bigtraj_fluctmatch/500ns/gcgc_21mer/mean_mode_npy/b0_backbone.std.npy
