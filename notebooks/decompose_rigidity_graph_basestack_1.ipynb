# %%
from os import path
import numpy as np
import matplotlib.pyplot as plt
from enmspring.graph_decompose import AtomImportance
from enmspring.vmddraw import BaseStackImportanceAgent
rootfolder = '/home/yizaochen/codes/dna_rna/fluctmatch_sequence'
svg_folder = '/home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1'

# %% [markdown]
# ### Part 1-1: A-tract-AA

# %%
host = 'a_tract_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND1'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms(figsize, strandid, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{strandid}.svg')
#plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_a_tract_single_A()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/a_tract_21mer_A_single

# %% [markdown]
# ### Part 1-2: A-tract-TT

# %%
figsize = (10, 4)
strandid = 'STRAND2'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms(figsize, strandid, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{strandid}.svg')
plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_a_tract_single_T()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/a_tract_21mer_A_single

# %% [markdown]
# ### Part 2-1: G-tract-GG

# %%
host = 'g_tract_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 231 eigenvectors belonging to STRAND1.
# There are 168 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND1'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms(figsize, strandid, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{strandid}.svg')
plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_g_tract_single_G()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/g_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/g_tract_21mer_G_single

# %% [markdown]
# ### Part 2-2: G-tract-CC

# %%
figsize = (10, 4)
strandid = 'STRAND2'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms(figsize, strandid, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{strandid}.svg')
plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_g_tract_single_C()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/g_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/g_tract_21mer_C_single

# %% [markdown]
# ### Part 3: ATAT

# %%
host = 'atat_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, rootfolder, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 200 eigenvectors belonging to STRAND1.
# There are 199 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 200 eigenvectors belonging to STRAND1.
# There are 199 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND1'
resname = 'T'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms_by_resname(figsize, strandid, resname, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{resname}_{strandid}.svg')
#plt.savefig(svg_out)
plt.show()
# Out:
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]
# [4, 6, 8, 10, 12, 14, 16, 18]

# %%
vmddraw_agent.vmd_show_atat_single_A()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/atat_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/atat_21mer_A_single

# %%
vmddraw_agent.vmd_show_atat_single_T()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/atat_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/atat_21mer_T_single

# %% [markdown]
# ### Part 4: GCGC

# %%
host = 'gcgc_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, rootfolder, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 201 eigenvectors belonging to STRAND1.
# There are 198 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 201 eigenvectors belonging to STRAND1.
# There are 198 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND2'
resname = 'G'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms_by_resname(figsize, strandid, resname, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{resname}_{strandid}.svg')
plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_gcgc_single_G()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/gcgc_21mer_G_single

# %%
vmddraw_agent.vmd_show_gcgc_single_C()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/gcgc_21mer_C_single

# %% [markdown]
# ### Part 5: CTCT

# %%
host = 'ctct_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, rootfolder, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 178 eigenvectors belonging to STRAND1.
# There are 221 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 178 eigenvectors belonging to STRAND1.
# There are 221 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND2'
resname = 'G'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms_by_resname(figsize, strandid, resname, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{resname}_{strandid}.svg')
#plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_ctct_single_C()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/ctct_21mer_C_single

# %%
vmddraw_agent.vmd_show_ctct_single_T()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/ctct_21mer_T_single

# %%
vmddraw_agent.vmd_show_ctct_single_A()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/ctct_21mer_A_single

# %%
vmddraw_agent.vmd_show_ctct_single_G()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/ctct_21mer_G_single

# %% [markdown]
# ### Part 6: TGTG

# %%
host = 'tgtg_21mer'
a_agent = AtomImportance(host, rootfolder)
vmddraw_agent = BaseStackImportanceAgent(host, rootfolder, svg_folder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure exists

# %%
figsize = (10, 4)
strandid = 'STRAND2'
resname = 'A'
start_mode = 1
end_mode = 10
bbox_to_anchor = (1.12, 0.5)
fig, ax = a_agent.plot_lambda_qTDq_respective_atoms_by_resname(figsize, strandid, resname, start_mode, end_mode, bbox_to_anchor)
plt.tight_layout()
svg_out = path.join(svg_folder, f'{host}_{resname}_{strandid}.svg')
plt.savefig(svg_out)
plt.show()

# %%
vmddraw_agent.vmd_show_tgtg_single_T()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/tgtg_21mer_T_single

# %%
vmddraw_agent.vmd_show_tgtg_single_G()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/tgtg_21mer_G_single

# %%
vmddraw_agent.vmd_show_tgtg_single_C()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/tgtg_21mer_C_single

# %%
vmddraw_agent.vmd_show_tgtg_single_A()
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# source /home/yizaochen/codes/dna_rna/enmspring/tclscripts/show_single_nucleotide.tcl
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance_1/mol_structure/tgtg_21mer_A_single
