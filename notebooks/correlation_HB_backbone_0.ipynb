# %%
from enmspring.correlation_window import HBAgent, BackboneAgent, StackAgent
bigtraj_folder = '/home/ytcdata/bigtraj_fluctmatch'
corr_folder = '/home/yizaochen/Documents/dna_2021_drawzone/correlation_1'

# %% [markdown]
# ### Part 1: Process All HB

# %%
host = 'atat_21mer'
h_agent = HBAgent(host, bigtraj_folder, corr_folder)

# %%
#h_agent.make_df()
# Out:
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2250_2750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/atat_21mer/bdna+bdna/2500_3000/pd_dfs exists
# ...

# %%
h_agent.df
# Out:
#     4-type1  4-type2  4-type3  5-type1  5-type2  5-type3  6-type1  6-type2  \
# 0    1.9473   4.2651   1.0795   1.6778   4.2818   0.7797   1.8569   4.2741
# 1    2.0660   4.0260   0.9899   1.7100   4.4503   0.7412   1.6429   4.3536
# 2    2.5285   3.6156   0.7147   1.9678   4.0989   0.8518   1.7426   5.1677
# 3    2.5121   3.5698   0.8681   2.3772   3.9177   0.8469   1.7736   4.7549
# 4    2.5428   3.9005   0.9226   1.9794   4.0016   0.8043   1.5234   4.1066
# 5    1.2615   0.3155   0.4245   1.9648   4.4127   0.8760   1.6876   4.2998
# 6    1.0823   0.4201   0.4208   2.2922   4.6214   0.8294   1.9300   4.9525
# 7    1.8086   3.8708   0.6482   2.2037   4.7310   0.8049   2.1705   4.9006
# 8    1.9007   3.3898   0.8313   1.9986   5.0628   0.7577   2.4142   4.4814
# 9    1.7294   2.8466   0.8550   2.2752   4.8452   0.6699   2.0949   3.3508
# 10   1.5940   2.8984   0.6448   2.5234   4.6438   0.6299   1.7696   3.4840
# ...

# %% [markdown]
# ### Part 2: Process All Backbone

# %%
host = 'atat_21mer'
strand_id = 'STRAND2'
b_agent = BackboneAgent(host, strand_id, bigtraj_folder, corr_folder)

# %%
#b_agent.make_df()

# %%
"""
hosts = ['a_tract_21mer', 'g_tract_21mer', 'gcgc_21mer']
strand_lst = ['STRAND1', 'STRAND2']
for host in hosts:
    for strand_id in strand_lst:
        b_agent = BackboneAgent(host, strand_id, bigtraj_folder, corr_folder)
        b_agent.make_df()
"""

# %%
b_agent.df
# Out:
#     3-4-BB1  3-4-BB2  3-4-BB3  3-3-BB4  3-3-BB5  4-5-BB1  4-5-BB2  4-5-BB3  \
# 0    2.1016   1.5767   3.7722  13.6737   6.3373   4.4732   6.0321      0.0
# 1    2.0718   1.6364   3.4270  13.2123   6.2831   5.1562   6.5299      0.0
# 2    2.2014   1.6865   3.4280  14.3126   6.3924   4.4533   5.3338      0.0
# 3    2.2304   1.2723   3.1190  11.6231   5.3540   3.8265   4.8290      0.0
# 4    2.4159   1.4233   3.2581  10.5610   5.0359   4.5494   4.9731      0.0
# 5    2.0877   1.9251   3.7727  14.0375   5.8585   5.6350   6.3498      0.0
# 6    2.1674   2.0137   3.3152  14.4869   5.8607   5.3792   6.0639      0.0
# 7    2.4222   1.7287   3.4297  14.2255   5.7635   4.6602   5.1590      0.0
# 8    1.8261   0.5726   1.8767   5.3063   3.3708   4.4956   5.8568      0.0
# 9    1.8867   0.7923   1.3647   5.4791   3.4114   5.4696   6.4931      0.0
# 10   1.6607   2.1470   0.9713   9.6600   4.4045   5.1700   5.6938      0.0
# ...

# %% [markdown]
# ### Part 3: Process All Stack

# %%
host = 'gcgc_21mer'
strand_id = 'STRAND2'
s_agent = StackAgent(host, strand_id, bigtraj_folder, corr_folder)

# %%
#s_agent.make_df()

# %%
s_agent.df
# Out:
#     3-4-ST1  4-5-ST1  5-6-ST1  6-7-ST1  7-8-ST1  8-9-ST1  9-10-ST1  10-11-ST1  \
# 0       0.0   1.4945      0.0   2.1057      0.0   2.3583       0.0     2.0255
# 1       0.0   1.4578      0.0   2.1815      0.0   1.8835       0.0     2.3044
# 2       0.0   1.5193      0.0   2.1984      0.0   1.9149       0.0     1.6619
# 3       0.0   1.7782      0.0   2.0792      0.0   2.5119       0.0     1.6727
# 4       0.0   2.0313      0.0   2.2496      0.0   2.4159       0.0     2.1911
# 5       0.0   2.1158      0.0   2.1953      0.0   2.3848       0.0     2.1283
# 6       0.0   1.9767      0.0   2.1908      0.0   2.4099       0.0     2.5739
# 7       0.0   1.8756      0.0   2.0370      0.0   2.4851       0.0     2.3629
# 8       0.0   1.7572      0.0   1.8571      0.0   2.5079       0.0     2.3180
# 9       0.0   1.8690      0.0   2.1085      0.0   2.4578       0.0     2.4916
# 10      0.0   1.5009      0.0   2.1465      0.0   2.4469       0.0     2.3764
# ...
