# %%
import numpy as np
from enmspring.graphs import GraphAgent, EigenPlot
import matplotlib.pyplot as plt
rootfolder = '/home/yizaochen/codes/dna_rna/fluctmatch_sequence'
rtol=1e-05
atol=1e-08

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'atat_21mer'
g_agent = GraphAgent(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists

# %%
g_agent.df_st.head()
# Out:
#     PairID PairType Big_Category Strand_i  Resid_i Atomname_i  Atomid_i  \
# 88      89  STACK-1        stack  STRAND1        1         N9         6
# 89      90  STACK-1        stack  STRAND1        1         N9         6
# 90      91  STACK-1        stack  STRAND1        1         N9         6
# 91      92  STACK-1        stack  STRAND1        1         N9         6
# 92      93  STACK-1        stack  STRAND1        1         N9         6
#
#    Strand_j  Resid_j Atomname_j  Atomid_j       k      b0
# 88  STRAND1        2         N1        27  0.0528  3.7869
# 89  STRAND1        2         C6        28  0.2731  3.4868
# 90  STRAND1        2         C5        29  0.3668  3.5589
# 91  STRAND1        2         C7        30  0.2704  3.9686
# 92  STRAND1        2         C4        31  0.1715  3.9515

# %%
g_agent.hb_agent.df_hb.head(5)
# Out:
#    index  PairID     PairType Big_Category Strand_i  Resid_i Atomname_i  \
# 0    194     195         HB-0           HB  STRAND1        1         N6
# 1    196     197         HB-0           HB  STRAND1        1         N6
# 2    212     213         HB-0           HB  STRAND1        1         N1
# 3    226     227  Oppo-Ring-0           HB  STRAND1        1         C2
# 4    441     442         HB-0           HB  STRAND1        2         O4
#
#    Atomid_i Strand_j  Resid_j Atomname_j  Atomid_j    k      b0
# 0        11  STRAND2       21         N3       850  0.0  2.9819
# 1        11  STRAND2       21         O2       852  0.0  2.0642
# 2        12  STRAND2       21         O2       852  0.0  3.0240
# 3        13  STRAND2       21         O2       852  0.0  4.0542
# 4        32  STRAND2       20         N6       828  0.0  2.9556

# %% [markdown]
# ### Part 2: Build Node List

# %%
g_agent.build_node_list_base()
print(f"Thare are {g_agent.n_node} nodes.")
# Out:
# Thare are 399 nodes.

# %% [markdown]
# ### Part 3: Build Adjacency Matrix

# %%
g_agent.build_adjacency_from_df_st_df_hb()

# %%
# Check Matrix Symmetrix
np.allclose(g_agent.adjacency_mat, g_agent.adjacency_mat.T, rtol=rtol, atol=atol)
# Out:
# True

# %% [markdown]
# ### Part 4: Build Degree Matrix

# %%
g_agent.build_degree_from_adjacency()

# %%
# Check diagonal matrix
np.allclose(g_agent.degree_mat, np.diag(np.diag(g_agent.degree_mat))) # check if diagonal
# Out:
# True

# %% [markdown]
# ### Part 5: Build Laplacian Matrix

# %%
g_agent.build_laplacian_by_adjacency_degree()
# Out:
# Finish the setup for Laplaican matrix.

# %%
# Check Matrix Symmetrix
np.allclose(g_agent.laplacian_mat, g_agent.laplacian_mat.T, rtol=rtol, atol=atol)
# Out:
# True

# %% [markdown]
# ### Part 6: Do Eigen-decomposition
# Reference: https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html

# %%
w, v = np.linalg.eig(g_agent.laplacian_mat)

# %%
# Sort
idx = w.argsort()[::-1]   
w = w[idx]
v = v[:,idx]

# %% [markdown]
# ### Part 7: Eigenvalue Plot

# %%
e_agent = EigenPlot(rootfolder, hb_include=True)

# %%
e_agent.initailize_six_systems()
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 398 eigenvectors belonging to STRAND1.
# There are 1 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 399 eigenvectors belonging to STRAND1.
# There are 0 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 399 eigenvectors belonging to STRAND1.
# There are 0 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 392 eigenvectors belonging to STRAND1.
# There are 7 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 399 eigenvectors belonging to STRAND1.
# There are 0 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 399 eigenvectors belonging to STRAND1.
# There are 0 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %%
figsize = (20, 10)
e_agent.plot_lambda_six_together(figsize)
#plt.savefig('Rigidity_graph_eigenvalue_basestack+hb.png', dpi=200)
plt.show()

# %% [markdown]
# ### Part 8: Eigenvector

# %%
figsize = (24, 12)
hspace = 0.18
wspace = 0.2
eigv_id_list = [1,2,3,4,5,6]
lw = 2
fig, d_axes = e_agent.plot_eigenvector(figsize, hspace, wspace, eigv_id_list, lw)
#plt.savefig('eigenvector_basestack+hb_1_6.png', dpi=200)
plt.show()

# %%
figsize = (24, 12)
hspace = 0.18
wspace = 0.2
eigv_id_list = [7,8,9,10,11,12]
lw = 2
fig, d_axes = e_agent.plot_eigenvector(figsize, hspace, wspace, eigv_id_list, lw)
#plt.savefig('eigenvector_basestack+hb_7_12.png', dpi=200)
plt.show()

# %%
figsize = (24, 12)
hspace = 0.18
wspace = 0.2
eigv_id_list = [13, 14, 15, 16, 17, 18]
lw = 2
fig, d_axes = e_agent.plot_eigenvector(figsize, hspace, wspace, eigv_id_list, lw)
#plt.savefig('eigenvector_basestack+hb_13_18.png', dpi=200)
plt.show()

# %%
figsize = (24, 12)
hspace = 0.18
wspace = 0.2
start = 100
eigv_id_list = range(start, start+6)
lw = 2
fig, d_axes = e_agent.plot_eigenvector(figsize, hspace, wspace, eigv_id_list, lw)
plt.show()

# %%
figsize = (24, 12)
hspace = 0.18
wspace = 0.2
start = 100
eigv_id_list = range(start, start+6)
lw = 2
fig, d_axes = e_agent.plot_eigenvector(figsize, hspace, wspace, eigv_id_list, lw)
plt.show()

# %% [markdown]
# ### Part 9: Observe

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 1
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'{host}   $\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()

# %%
sele_id = 10
w_sele = w[sele_id-1]
v_sele = v[:, sele_id-1]
x = range(1, g_agent.n_node+1)

fig, ax = plt.subplots(figsize=(20, 4))
title = f'$\lambda_{sele_id}=$' + f'{w_sele:.2f}'
ax.set_title(title)
ax.vlines(x, 0, v_sele, colors='b', lw=4)
ax.set_xlabel("CG-bead ID")
ax.set_ylabel("Eigenvector")
ax.set_xlim(1, g_agent.n_node+1)

plt.show()
