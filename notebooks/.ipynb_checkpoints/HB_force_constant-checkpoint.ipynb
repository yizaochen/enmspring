# %%
import matplotlib.pyplot as plt
from enmspring.spring import Spring
from enmspring.k_b0_util import get_df_by_filter_bp
from enmspring.hb_util import HBAgent, HBSixPlot, HBTwoBarPlots, HBAgentBigTraj

rootfolder = '/home/yizaochen/codes/dna_rna/fluctmatch_sequence'

# %% [markdown]
# ### Part 1: Residue ID vs $k_{HB}$

# %%
# Parameters for plot
figsize = (12, 20)
lbfz = 12
lgfz = 12 
ttfz = 14
title_pos = (1, 9)

# %%
plot_agent = HBSixPlot(figsize, rootfolder, lbfz, lgfz, ttfz, title_pos)
plot_agent.main()
#plt.savefig('hb_sixplot.svg')
plt.show()
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# ...

# %% [markdown]
# ### Part 2: Bar Plot for GC and AT type

# %%
# Parameters for plot
figsize = (12, 6)
lbfz = 12
lgfz = 12 
ttfz = 14
title_pos = (0.05, 8.8)

# %%
plot_agent = HBTwoBarPlots(figsize, rootfolder, lbfz, lgfz, ttfz, title_pos)
plot_agent.main()
plt.savefig('hb_twobarplot.svg')
plt.show()
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# ...

# %% [markdown]
# ### Part 3: Single plot for a specific host

# %%
host = 'a_tract_21mer'
n_bp = 21
h_agent = HBAgent(host, rootfolder, n_bp)
h_agent.initialize_basepair()
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists

# %%
xticks = range(1, 22)
ylim = (-0.5, 10)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14,5))

typename = 'type1'
resids, klist = h_agent.get_resid_klist_all(typename)
ax.plot(resids, klist, '-o', label=typename)

typename = 'type2'
resids, klist = h_agent.get_resid_klist_all(typename)
ax.plot(resids, klist, '-o', label=typename)

typename = 'type3'
resids, klist = h_agent.get_resid_klist_all(typename)
ax.plot(resids, klist, '-o', label=typename)

ax.set_title(host, fontsize=14)
ax.legend(fontsize=14)
ax.set_xticks(xticks)
ax.axvline(3, color='red', alpha=0.5)
ax.axvline(19, color='red', alpha=0.5)
ax.axhline(6, color='grey', alpha=0.4)
ax.axhline(2, color='grey', alpha=0.4)
ax.tick_params(axis='both', labelsize=14)
ax.set_xlabel('Resid', fontsize=14)
ax.set_ylabel('k (kcal/mol/Å$^2$)', fontsize=14)
ax.set_ylim(ylim)

plt.tight_layout()
plt.savefig(f'{host}_hb.png', dpi=200)
plt.show()

# %% [markdown]
# ### Part 4: Single plot for a specific host (include big-traj 9 windows)

# %%
host = 'a_tract_21mer'
bigtraj_folder = '/home/ytcdata/bigtraj_fluctmatch'
n_bp = 21
only_central = False

h_agent = HBAgentBigTraj(host, bigtraj_folder, n_bp, only_central)
h_agent.initialize_basepair()
# Out:
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/0_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/500_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/1000_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/1500_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/2000_3000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/2500_3500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/3000_4000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/3500_4500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/4000_5000/pd_dfs exists
# Read /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/0_1000/pd_dfs/pairtypes_k_b0_cutoff_4.70.csv into df_all_k
# Read /home/ytcdata/bigtraj_fluctmatch/a_tract_21mer/bdna+bdna/500_1500/pd_dfs/pairtypes_k_b0_cutoff_4.70.csv into df_all_k
# ...

# %%
typename = 'type1'
resids, kmean, kstd = h_agent.get_resid_klist_all(typename)

# %%
xticks = range(1, 22)
ylim = (-0.5, 10)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14,5))

typename = 'type1'
resids, kmean, kstd = h_agent.get_resid_klist_all(typename)
ax.plot(resids, kmean, '-o', label=typename)

typename = 'type2'
resids, kmean, kstd = h_agent.get_resid_klist_all(typename)
ax.plot(resids, kmean, '-o', label=typename)

typename = 'type3'
resids, kmean, kstd = h_agent.get_resid_klist_all(typename)
ax.plot(resids, kmean, '-o', label=typename)

ax.set_title(host, fontsize=14)
ax.legend(fontsize=14)
ax.set_xticks(xticks)
ax.axvline(3, color='red', alpha=0.5)
ax.axvline(19, color='red', alpha=0.5)
ax.axhline(6, color='grey', alpha=0.4)
ax.axhline(2, color='grey', alpha=0.4)
ax.tick_params(axis='both', labelsize=14)
ax.set_xlabel('Resid', fontsize=14)
ax.set_ylabel('k (kcal/mol/Å$^2$)', fontsize=14)
#ax.set_ylim(ylim)

plt.tight_layout()
plt.savefig(f'{host}_hb.png', dpi=200)
plt.show()
