# %%
from enmspring.hb_st_scatter import HBAgentv0, StackAgentv0, BackboneAgentv0
bigtraj_folder = '/home/ytcdata/bigtraj_fluctmatch'
corr_folder = '/home/yizaochen/Documents/dna_2021_drawzone/correlation_1'

# %% [markdown]
# ### Part 1: Process All HB

# %%
host = 'g_tract_21mer'
h_agent = HBAgentv0(host, bigtraj_folder, corr_folder)

# %%
h_agent.read_df()
# Out:
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_hb.csv

# %%
h_agent.get_hb_array()
# Out:
# array([289.51  , 295.7577, 313.1898, 312.4352, 304.4339, 302.4145,
#        280.4927, 277.9296, 284.9709, 301.123 , 325.8244, 317.0287,
#        303.4371, 300.4963, 275.4464, 281.1995, 306.7776, 302.2067,
#        303.4068])

# %%
h_agent.df
# Out:
#     4-type1  4-type2  4-type3  5-type1  5-type2  5-type3  6-type1  6-type2  \
# 0    1.9473   4.2651   1.0795   1.6778   4.2818   0.7797   1.8569   4.2741
# 1    2.0660   4.0260   0.9899   1.7100   4.4503   0.7412   1.6429   4.3536
# 2    2.5285   3.6156   0.7147   1.9678   4.0989   0.8518   1.7426   5.1677
# 3    2.5121   3.5698   0.8681   2.3772   3.9177   0.8469   1.7736   4.7549
# 4    2.5428   3.9005   0.9226   1.9794   4.0016   0.8043   1.5234   4.1066
# 5    1.2615   0.3155   0.4245   1.9648   4.4127   0.8760   1.6876   4.2998
# 6    1.0823   0.4201   0.4208   2.2922   4.6214   0.8294   1.9300   4.9525
# 7    1.8086   3.8708   0.6482   2.2037   4.7310   0.8049   2.1705   4.9006
# 8    1.9007   3.3898   0.8313   1.9986   5.0628   0.7577   2.4142   4.4814
# 9    1.7294   2.8466   0.8550   2.2752   4.8452   0.6699   2.0949   3.3508
# 10   1.5940   2.8984   0.6448   2.5234   4.6438   0.6299   1.7696   3.4840
# ...

# %% [markdown]
# ### Part 2: Process All Stack

# %%
host = 'atat_21mer'
s_agent = StackAgentv0(host, bigtraj_folder, corr_folder)

# %%
#s_agent.make_df()

# %%
s_agent.df
# Out:
#            k
# 0   908.1891
# 1   891.0900
# 2   907.7033
# 3   912.1386
# 4   902.8162
# 5   872.7065
# 6   864.2846
# 7   914.7592
# 8   869.0498
# 9   859.7891
# 10  855.5129
# 11  835.8782
# 12  870.8723
# 13  916.8445
# 14  906.8977
# 15  890.3561
# 16  865.6886
# 17  833.5945
# 18  815.8115

# %% [markdown]
# ### Part 3: Process All Backbone

# %%
host = 'atat_21mer'
s_agent = BackboneAgentv0(host, bigtraj_folder, corr_folder)

# %%
#s_agent.make_df()

# %%
s_agent.read_df()

# %%
s_agent.df
# Out:
#             k
# 0   4003.8318
# 1   4022.8185
# 2   4111.4232
# 3   3963.6441
# 4   3905.7631
# 5   3891.9462
# 6   4018.1208
# 7   4057.5827
# 8   3867.6324
# 9   3822.6106
# 10  3862.9678
# 11  3555.2437
# 12  3742.7831
# 13  3994.6556
# 14  3966.1261
# 15  3964.7899
# 16  3883.9728
# 17  3871.1425
# 18  3745.3510
