# %%
import matplotlib.pyplot as plt
import numpy as np
from enmspring.graphs_bigtraj import ProminentModes
from enmspring.abbr import Abbreviation

rootfolder = '/home/ytcdata/bigtraj_fluctmatch/500ns'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
interval_time = 500
p_agent = ProminentModes(host, rootfolder, interval_time)
# Out:
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/0_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/250_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/500_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/750_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1000_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1250_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1500_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1750_2250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2000_2500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2250_2750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2500_3000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2750_3250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3000_3500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3250_3750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3500_4000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/3750_4250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4000_4500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4250_4750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/4500_5000/pd_dfs exists
# Read Dataframe of stacking: df_st
# Load laplacian_mat from /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/laplacian.npy

# %% [markdown]
# ### Part 2: Initialize all small agents

# %%
execute = True
if execute:
    p_agent.initialize_small_agents()
# Out:
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 209 eigenvectors belonging to STRAND1.
# There are 190 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 211 eigenvectors belonging to STRAND1.
# There are 188 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# ### Part 3: Make/Read $\left< r_{\alpha '}\right>$

# %%
p_agent.set_mean_r_alpha_array()
p_agent.save_mean_r_alpha_array()
# Out:
# Save mean_r_alpha_array into /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/mean_r_alpha.npy

# %%
p_agent.load_mean_r_alpha_array()
# Out:
# Load mean_r_alpha_array from /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy/mean_r_alpha.npy

# %% [markdown]
# ### Part 4: Plot

# %%
hosts = ['a_tract_21mer', 'tat_21mer', 'g_tract_21mer', 'gcgc_21mer']
d_axes_col_row = {'a_tract_21mer': (0,0), 'tat_21mer': (0,1), 'g_tract_21mer': (1,0), 'gcgc_21mer': (1,1)}
d_data = dict()
for host in hosts:
    p_agent = ProminentModes(host, rootfolder, interval_time)
    p_agent.load_mean_r_alpha_array()
    d_data[host] = {'mean_r_alpha_array': p_agent.mean_r_alpha_array, 'lambda_array': p_agent.mean_modes_w}
# Out:
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/0_250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/125_375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/250_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/375_625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/500_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/625_875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/750_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/875_1125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1000_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1125_1375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1250_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1375_1625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1500_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1625_1875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1750_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/1875_2125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2000_2250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2125_2375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2250_2500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2375_2625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2500_2750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2625_2875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2750_3000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/2875_3125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3000_3250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3125_3375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3250_3500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3375_3625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3500_3750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3625_3875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3750_4000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/3875_4125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4000_4250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4125_4375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4250_4500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4375_4625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4500_4750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4625_4875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/bdna+bdna/4750_5000/pd_dfs exists
# Read Dataframe of stacking: df_st
# Load laplacian_mat from /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/mean_mode_npy/laplacian.npy
# Load mean_r_alpha_array from /home/ytcdata/bigtraj_fluctmatch/250ns/a_tract_21mer/mean_mode_npy/mean_r_alpha.npy
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/0_250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/125_375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/250_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/375_625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/500_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/625_875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/750_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/875_1125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1000_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1125_1375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1250_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1375_1625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1500_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1625_1875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1750_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/1875_2125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2000_2250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2125_2375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2250_2500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2375_2625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2500_2750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2625_2875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2750_3000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/2875_3125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3000_3250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3125_3375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3250_3500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3375_3625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3500_3750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3625_3875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3750_4000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/3875_4125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4000_4250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4125_4375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4250_4500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4375_4625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4500_4750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4625_4875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/bdna+bdna/4750_5000/pd_dfs exists
# Read Dataframe of stacking: df_st
# Load laplacian_mat from /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/mean_mode_npy/laplacian.npy
# Load mean_r_alpha_array from /home/ytcdata/bigtraj_fluctmatch/250ns/tat_21mer/mean_mode_npy/mean_r_alpha.npy
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/0_250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/125_375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/250_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/375_625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/500_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/625_875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/750_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/875_1125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1000_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1125_1375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1250_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1375_1625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1500_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1625_1875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1750_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/1875_2125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2000_2250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2125_2375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2250_2500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2375_2625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2500_2750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2625_2875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2750_3000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/2875_3125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3000_3250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3125_3375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3250_3500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3375_3625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3500_3750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3625_3875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3750_4000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/3875_4125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4000_4250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4125_4375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4250_4500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4375_4625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4500_4750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4625_4875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/bdna+bdna/4750_5000/pd_dfs exists
# Read Dataframe of stacking: df_st
# Load laplacian_mat from /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/mean_mode_npy/laplacian.npy
# Load mean_r_alpha_array from /home/ytcdata/bigtraj_fluctmatch/250ns/g_tract_21mer/mean_mode_npy/mean_r_alpha.npy
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/0_250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/125_375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/250_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/375_625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/500_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/625_875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/750_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/875_1125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1000_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1125_1375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1250_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1375_1625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1500_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1625_1875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1750_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/1875_2125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2000_2250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2125_2375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2250_2500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2375_2625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2500_2750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2625_2875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2750_3000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/2875_3125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3000_3250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3125_3375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3250_3500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3375_3625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3500_3750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3625_3875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3750_4000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/3875_4125/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4000_4250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4125_4375/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4250_4500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4375_4625/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4500_4750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4625_4875/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/bdna+bdna/4750_5000/pd_dfs exists
# Read Dataframe of stacking: df_st
# Load laplacian_mat from /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/mean_mode_npy/laplacian.npy
# Load mean_r_alpha_array from /home/ytcdata/bigtraj_fluctmatch/250ns/gcgc_21mer/mean_mode_npy/mean_r_alpha.npy

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8), facecolor="white")

ylims = (0,1.05)
xlims = (-1,20.5)

for host in hosts:
    ax = axes[d_axes_col_row[host]]
    x = d_data[host]['lambda_array']
    y = d_data[host]['mean_r_alpha_array']
    ax.scatter(x, y, s=5)
    ax.set_xlabel(r'$\lambda_{\alpha}$', fontsize=14)
    ax.set_ylabel(r'$\left< r_{\alpha}\right>$', fontsize=14)
    ax.set_xlim(xlims)
    ax.set_ylim(ylims)
    title = Abbreviation.get_abbreviation(host)
    ax.set_title(title,fontsize=16)

plt.tight_layout()
#plt.savefig('/home/yizaochen/Desktop/drawzone_temp/prominent_mode_250ns.png', dpi=200, transparent=False)
plt.show()

# %% [markdown]
# ### Batch Run

# %%
hosts = ['a_tract_21mer', 'g_tract_21mer', 'gcgc_21mer', 'tat_21mer']
interval_time = 500
for host in hosts:
    p_agent = ProminentModes(host, rootfolder, interval_time)
    #p_agent.initialize_small_agents()
    #p_agent.set_mean_r_alpha_array()
    #p_agent.save_mean_r_alpha_array()
