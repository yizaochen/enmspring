# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from enmspring.prominent_plot import ScatterTwoStrand

rootfolder = '/home/ytcdata/bigtraj_fluctmatch/500ns'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
interval_time = 500
figsize = (8,8)
plot_agent = ScatterTwoStrand(host, rootfolder, interval_time, figsize)
# Out:
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/0_500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/250_750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/500_1000/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/750_1250/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1000_1500/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1250_1750/pd_dfs exists
# Read Dataframe of stacking: df_st
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1500_2000/pd_dfs exists
# Read Dataframe of stacking: df_st
# ...

# %% [markdown]
# ### Part 2: Plot

# %%
ylims = (0.4, 1.05)
xlims = (-1, 21.5)
d_criteria_mean_mode_lambda = {'STRAND1': 14.5, 'STRAND2': 13.2}
d_criteria_mean_r_alpha = {'STRAND1': None, 'STRAND2': None}
addtext = True

fig, axes = plot_agent.plot_main(d_criteria_mean_mode_lambda, xlims, ylims, addtext)

plt.tight_layout()
#plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/prominent_mode_{host}.png', dpi=200, transparent=False)
plt.show()

# %% [markdown]
# ### Part 3: Get the index of eigenvector based on $\lambda_{\alpha}$ and $\left<r_{\alpha} \right>$

# %%
strand_id_sele = 'STRAND1'
df = plot_agent.get_df_by_strand(strand_id_sele)

# %%
criteria_mean_r_alpha = 0.9
mask = df['Mean-r-alpha'] >= criteria_mean_r_alpha
df[mask]
# Out:
#      Mode-ID  Mean-r-alpha  Mean-Mode-lambda Strand-ID
# 0          1      0.977170      1.964421e+01   STRAND1
# 1          2      0.959884      1.850491e+01   STRAND1
# 2          3      0.948974      1.756274e+01   STRAND1
# 3          4      0.942812      1.679124e+01   STRAND1
# 4          5      0.908216      1.590810e+01   STRAND1
# 6          7      0.947018      1.483456e+01   STRAND1
# 7          8      0.902595      1.427470e+01   STRAND1
# 397      398      0.979992      1.201274e-14   STRAND1

# %%
criteria_mean_mode_lambda = 14
mask = df['Mean-Mode-lambda'] >= criteria_mean_mode_lambda
df[mask]
# Out:
#    Mode-ID  Mean-r-alpha  Mean-Mode-lambda Strand-ID
# 0        1      0.977170         19.644212   STRAND1
# 1        2      0.959884         18.504910   STRAND1
# 2        3      0.948974         17.562744   STRAND1
# 3        4      0.942812         16.791244   STRAND1
# 4        5      0.908216         15.908097   STRAND1
# 5        6      0.872467         14.973494   STRAND1
# 6        7      0.947018         14.834563   STRAND1
# 7        8      0.902595         14.274695   STRAND1
# 8        9      0.852512         14.063150   STRAND1
