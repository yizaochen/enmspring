# %%
from enmspring.graphs_bigtraj import BackboneMeanModeAgent
from enmspring.backbone_k import BackboneRiboseK
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

big_traj_folder = '/home/ytcdata/bigtraj_fluctmatch/500ns'
df_folder = '/home/yizaochen/Documents/dna_2021_drawzone/backbone_k'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
br_agent = BackboneRiboseK(host, big_traj_folder, df_folder)

# %% [markdown]
# ### Part 2: Make/Read arranged dataframe

# %%
make_dataframe = False
if make_dataframe:
    br_agent.initialize_mean_mode_agent()
    br_agent.make_df()
# Out:
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/mean_mode_npy exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/0_500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/250_750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/500_1000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/750_1250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1000_1500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1250_1750/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1500_2000/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/1750_2250/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2000_2500/pd_dfs exists
# /home/ytcdata/bigtraj_fluctmatch/500ns/a_tract_21mer/bdna+bdna/2250_2750/pd_dfs exists
# ...

# %%
br_agent.read_df()
# Out:
# Read DataFrame from /home/yizaochen/Documents/dna_2021_drawzone/backbone_k/a_tract_21mer.csv

# %%
br_agent.df.head()
# Out:
#      PairType Big_Category Strand_i  Resid_i Atomname_i Strand_j  Resid_j  \
# 0  same-P-P-0     backbone  STRAND1        1        O5'  STRAND1        1
# 1  same-P-S-0     backbone  STRAND1        1        O5'  STRAND1        1
# 2  same-P-S-0     backbone  STRAND1        1        O5'  STRAND1        1
# 3  same-P-P-0     backbone  STRAND1        1        C5'  STRAND1        1
# 4  same-P-S-0     backbone  STRAND1        1        C5'  STRAND1        1
#
#   Atomname_j     k-mean     k-std        b0    b0-std
# 0        C5'   0.356563  0.112825  1.952247  0.001147
# 1        C4'   0.269289  0.170900  2.304158  1.190102
# 2        O4'   0.196763  0.041213  3.323789  0.138322
# 3        O5'   0.356563  0.112825  1.952247  0.001147
# 4        C4'  14.476316  7.172439  1.540274  0.000513

# %% [markdown]
# ### Part 2: PP0

# %%
figsize = (4, 8)
category = 'PP0'
br_agent.plot_kmean_by_resid(figsize, category, ylim=None)
plt.tight_layout()
plt.show()

# %%
s_agent.process_first_small_agent()
# Out:
# Thare are 855 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 855
# There are 438 eigenvectors belonging to STRAND1.
# There are 417 eigenvectors belonging to STRAND2.
# Sum of two strands: 855

# %%
s_agent.node_list[:5]
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5']

# %%
s_agent.laplacian_mat
# Out:
# array([[ 0.90668947,  0.35656316,  0.26928947, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.35656316, 27.11303158, 14.47631579, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.26928947, 14.47631579, 80.08884211, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 39.71699474,
#          7.81132632,  7.10229474],
#        [ 0.        ,  0.        ,  0.        , ...,  7.81132632,
#         39.14473684,  2.47442105],
#        [ 0.        ,  0.        ,  0.        , ...,  7.10229474,
#          2.47442105, 14.69616842]])

# %%
s_agent.initialize_all_maps()

# %%
s_agent.atomname_map
# Out:
# {'A1': "O5'",
#  'A2': "C5'",
#  'A3': "C4'",
#  'A4': "O4'",
#  'A5': "C1'",
#  'A6': 'N9',
#  'A7': 'C8',
#  'A8': 'N7',
#  'A9': 'C5',
#  'A10': 'C6',
#  'A11': 'N6',
#  'A12': 'N1',
#  'A13': 'C2',
#  'A14': 'N3',
#  'A15': 'C4',
#  'A16': "C3'",
#  'A17': "C2'",
#  'A18': "O3'",
#  'A19': 'P',
#  'A20': 'O1P',
#  'A21': 'O2P',
#  'A22': "O5'",
#  'A23': "C5'",
#  'A24': "C4'",
#  'A25': "O4'",
#  'A26': "C1'",
#  'A27': 'N9',
#  'A28': 'C8',
#  'A29': 'N7',
#  'A30': 'C5',
#  'A31': 'C6',
#  'A32': 'N6',
#  'A33': 'N1',
#  'A34': 'C2',
#  'A35': 'N3',
#  'A36': 'C4',
#  'A37': "C3'",
#  'A38': "C2'",
#  'A39': "O3'",
#  'A40': 'P',
#  'A41': 'O1P',
#  'A42': 'O2P',
#  'A43': "O5'",
#  'A44': "C5'",
#  'A45': "C4'",
#  'A46': "O4'",
#  'A47': "C1'",
#  'A48': 'N9',
#  'A49': 'C8',
#  'A50': 'N7',
#  'A51': 'C5',
#  'A52': 'C6',
#  'A53': 'N6',
#  'A54': 'N1',
#  'A55': 'C2',
#  'A56': 'N3',
#  'A57': 'C4',
#  'A58': "C3'",
#  'A59': "C2'",
#  'A60': "O3'",
#  'A61': 'P',
# ...

# %%
test = np.random.rand(5,4,3)

# %%
for k in range(3):
    test[0,0,k] = 1

# %%
test.std(2)
# Out:
# array([[0.        , 0.02579943, 0.18943602, 0.20474476],
#        [0.1593184 , 0.20537995, 0.1663517 , 0.21634328],
#        [0.25748769, 0.25296482, 0.21704104, 0.35203306],
#        [0.26418073, 0.27245205, 0.30394471, 0.06217889],
#        [0.24409961, 0.06250639, 0.08342702, 0.12248422]])
