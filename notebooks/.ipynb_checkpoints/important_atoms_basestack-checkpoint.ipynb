# %%
from os import path
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from enmspring.graphs import Stack
from enmspring.importance_atom import StackPlot
rootfolder = '/home/yizaochen/codes/dna_rna/fluctmatch_sequence'
enmroot = '/home/yizaochen/codes/dna_rna/enmspring'
pic_out_folder = '/home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance'

# %% [markdown]
# ### Part 1: A-tract

# %%
host = 'a_tract_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/a_tract_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### Overview

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_RR_YY_homo(figsize, start_mode, end_mode)
plt.tight_layout()
#plt.savefig('at_base_importance.svg')
plt.show()

# %% [markdown]
# #### 5'-AA-3'

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.a_tract_aa(figsize, start_mode, end_mode)
plt.tight_layout()
#plt.savefig('a_tract_aa_base_importance.svg')
plt.show()

# %%
resid = 7
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N1', 'N6', 'C6']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'N3', 'C4', 'C5', 'N7']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_aaaa_mol_fourmer')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 7 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 7 and name N1 N6 C6
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 7 and name C2 N3 C4 C5 N7
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 7 and name C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/a_tract_21mer_aaaa_mol_fourmer

# %% [markdown]
# #### 5'-TT-3'

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.a_tract_tt(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, 'a_tract_tt_base_importance.svg')
#plt.savefig(pic_out)
plt.show()

# %%
resid = 27

plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N1', 'C2', 'N3', 'C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C6', 'C7']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['O2', 'O4']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_tttt_mol_fourmer')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/a_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 27 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 27 and name N1 C2 N3 C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 27 and name C6 C7
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 27 and name O2 O4
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/a_tract_21mer_tttt_mol_fourmer

# %% [markdown]
# ### Part 2: G-tract

# %%
host = 'g_tract_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/g_tract_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 231 eigenvectors belonging to STRAND1.
# There are 168 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### Overview

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_RR_YY_homo(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_overview.svg')
#plt.savefig(pic_out)
plt.show()

# %% [markdown]
# #### 5'-GG-3'

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.g_tract_gg(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_gg_base_importance.svg')
#plt.savefig(pic_out)
plt.show()

# %%
resid = 7
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N1', 'C6', 'O6']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'N2', 'N3', 'C4', 'C5', 'N7']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_ggg_mol_threemer')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/g_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 7 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 7 and name N1 C6 O6
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 7 and name C2 N2 N3 C4 C5 N7
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 7 and name C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/g_tract_21mer_ggg_mol_threemer

# %% [markdown]
# #### 5'-CC-3'

# %%
figsize = (12, 4)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.g_tract_cc(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_cc_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 28
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C2', 'C5', 'C4']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N3', 'N4']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'O2', 'C6']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_ccc_mol_threemer')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/g_tract_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 28 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 28 and name C2 C5 C4
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 28 and name N3 N4
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 28 and name N1 O2 C6
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/g_tract_21mer_ccc_mol_threemer

# %% [markdown]
# ### Part 3: ATAT-21mer

# %%
host = 'atat_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 200 eigenvectors belonging to STRAND1.
# There are 199 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### Overview

# %%
figsize = (12, 12)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_YR(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, 'overview', f'{host}_overview.svg')
plt.savefig(pic_out)
plt.show()

# %% [markdown]
# #### ATAT

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.atat(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_base_importance.svg')
#plt.savefig(pic_out)
plt.show()

# %%
resid = 5
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4', 'C5', 'C6']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C2', 'N3']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N6', 'N7', 'C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_atat_mol_fourmer')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/atat_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 5 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 5 and name C4 C5 C6
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 5 and name N1 C2 N3
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 5 and name N6 N7 C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/atat_21mer_atat_mol_fourmer

# %%
resid = 6
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'N3']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'O4', 'O2', 'C6', 'C7']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_t_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/atat_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 6 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 6 and name C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 6 and name C2 N3
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 6 and name N1 O4 O2 C6 C7
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/atat_21mer_t_mol

# %% [markdown]
# ### Part 4: GCGC-21mer

# %%
host = 'gcgc_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/gcgc_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 201 eigenvectors belonging to STRAND1.
# There are 198 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### Overview

# %%
figsize = (12, 12)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_YR(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, 'overview', f'{host}_overview.svg')
plt.savefig(pic_out)
plt.show()

# %% [markdown]
# #### GCGC

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.gcgc(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 1
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C2', 'N3', 'C6']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N2', 'O6', 'N7', 'C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_g_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 1 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 1 and name C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 1 and name N1 C2 N3 C6
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 1 and name N2 O6 N7 C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/gcgc_21mer_g_mol

# %%
resid = 2
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C2', 'N3', 'C4']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['O2', 'N4', 'C5']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C6']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_c_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/gcgc_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 2 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 2 and name C2 N3 C4
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 2 and name O2 N4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 2 and name N1 C6
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/gcgc_21mer_c_mol

# %% [markdown]
# ### Part 5: CTCT-21mer

# %%
host = 'ctct_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/ctct_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 178 eigenvectors belonging to STRAND1.
# There are 221 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### Overview

# %%
figsize = (12, 12)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_hetero(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, 'overview', f'{host}_overview.svg')
plt.savefig(pic_out)
plt.show()

# %% [markdown]
# #### CT

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.ctct_ct(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_ct_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 1
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N1', 'C2', 'N3']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C4', 'N4']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C5', 'C6', 'O2']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_c_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 1 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 1 and name N1 C2 N3
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 1 and name C4 N4
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 1 and name C5 C6 O2
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/ctct_21mer_c_mol

# %%
resid = 2
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'O2', 'N3', 'C7']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'O4', 'C6']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_t_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 2 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 2 and name C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 2 and name C2 O2 N3 C7
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 2 and name N1 O4 C6
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/ctct_21mer_t_mol

# %% [markdown]
# #### GA

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.ctct_ga(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_ga_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 22
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N1', 'C5', 'C6']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'N3', 'C4','O6']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N2', 'N7', 'C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_g_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 22 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 22 and name N1 C5 C6
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 22 and name C2 N3 C4 O6
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 22 and name N2 N7 C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/ctct_21mer_g_mol

# %%
resid = 23
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C6']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C4', 'C5', 'N6']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2', 'N3', 'N7', 'C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_a_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/ctct_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 23 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 23 and name C6
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 23 and name N1 C4 C5 N6
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 23 and name C2 N3 N7 C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/ctct_21mer_a_mol

# %% [markdown]
# ### Part 6: TGTG-21mer

# %%
host = 'tgtg_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/tgtg_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 210 eigenvectors belonging to STRAND1.
# There are 189 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %% [markdown]
# #### overview

# %%
figsize = (12, 12)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.overview_hetero(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, 'overview', f'{host}_overview.svg')
plt.savefig(pic_out)
plt.show()

# %% [markdown]
# #### TG

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.tgtg_tg(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_tg_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 1
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['N3', 'C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C2']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'O2', 'O4', 'C6', 'C7']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_t_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 1 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 1 and name N3 C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 1 and name C2
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 1 and name N1 O2 O4 C6 C7
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/tgtg_21mer_t_mol

# %%
resid = 2
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C2', 'N2', 'N3', 'C5', 'C6', 'N9']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N7', 'O6', 'C8']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_g_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 2 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 2 and name C4
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 2 and name N1 C2 N2 N3 C5 C6 N9
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 2 and name N7 O6 C8
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/tgtg_21mer_g_mol

# %% [markdown]
# #### AC

# %%
figsize = (12, 8)
start_mode = 1
end_mode = 10
fig, axes = plot_agent.tgtg_ac(figsize, start_mode, end_mode)

plt.tight_layout()
pic_out = path.join(pic_out_folder, f'{host}_ac_base_importance.svg')
plt.savefig(pic_out)
plt.show()

# %%
resid = 22
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C4', 'C5']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'C2', 'N3', 'N6', 'C6', 'N7']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['C8', 'N9']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_a_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 22 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 22 and name C4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 22 and name N1 C2 N3 N6 C6 N7
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 22 and name C8 N9
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/tgtg_21mer_a_mol

# %%
resid = 23
plot_agent.vmd_show_atom_importance(resid)

atomlist = ['C2', 'N3', 'C4']
colorid = 0
cpkradius = 1.2
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N4', 'C5']
colorid = 1
cpkradius = 0.9
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

atomlist = ['N1', 'O2', 'C6']
colorid = 5
cpkradius = 0.5
plot_agent.vmd_add_atomlist_vdw(atomlist, resid, colorid, cpkradius)

tga_out = path.join(pic_out_folder, 'mol_structure', f'{host}_c_mol')
print(tga_out)
# Out:
# vmd -gro /home/yizaochen/codes/dna_rna/all_systems/tgtg_21mer/bdna+bdna/input/allatoms/bdna+bdna.perfect.gro
# The following in tk console:
# mol delrep 0 0
# mol color ColorID 2
# mol representation Licorice 0.100000 12.000000 12.000000
# mol selection resid 23 and not hydrogen and not (name C1' C2' O4' C3' C4' C5' P O1P O2P O5' O3')
# mol material Opaque
# mol addrep 0
# mol color ColorID 0
# mol representation CPK 1.200 0.200000 12.000000 12.000000
# mol selection resid 23 and name C2 N3 C4
# mol material Opaque
# mol addrep 0
# mol color ColorID 1
# mol representation CPK 0.900 0.200000 12.000000 12.000000
# mol selection resid 23 and name N4 C5
# mol material Opaque
# mol addrep 0
# mol color ColorID 5
# mol representation CPK 0.500 0.200000 12.000000 12.000000
# mol selection resid 23 and name N1 O2 C6
# mol material Opaque
# mol addrep 0
# /home/yizaochen/Documents/JPCL_ytc_2021/images/atom_importance/mol_structure/tgtg_21mer_c_mol

# %% [markdown]
# ### Part 3: Make filter

# %%
host = 'a_tract_21mer'
plot_agent = StackPlot(host, rootfolder)

# %%
sele_name = 'C8'
sele_strandid = 'STRAND1'
filter_given = plot_agent.g_agent.get_filter_by_atomname_strandid(sele_name, sele_strandid)

# %%
lw = 2
x = range(1, g_agent.n_node+1)
lbfz = 16
tkfz = 12

fig, ax = plt.subplots(figsize=(8,4))
ax.vlines(x, 0, filter_given, colors='cyan', lw=lw)
ax.set_ylim(0,1)
ax.set_xticks(x[::50])
ax.set_xlabel("Atom Index", fontsize=lbfz)
ax.set_ylabel(r"$\vec{v}_{\mathrm{filter}}$", fontsize=lbfz)
title = r'$|\vec{v}_{\mathrm{filter}}|=1$'
ax.set_title(title, fontsize=lbfz)
ax.tick_params(axis='both', labelsize=tkfz)
plt.tight_layout()
#plt.savefig('filter_example.svg')
plt.show()

# %%
host = 'atat_21mer'
plot_agent = StackPlot(host, rootfolder)
# Out:
# /home/yizaochen/codes/dna_rna/fluctmatch_sequence/atat_21mer/bdna+bdna/pd_dfs exists
# Read Dataframe of stacking: df_st
# Thare are 399 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Total number of nodes: 399
# There are 200 eigenvectors belonging to STRAND1.
# There are 199 eigenvectors belonging to STRAND2.
# Sum of two strands: 399

# %%
sele_name = 'C6'
sele_strandid = 'STRAND1'
sele_resname = 'A' # A, T, C, G
filter_given = plot_agent.g_agent.get_filter_by_atomname_for_YR(sele_name, sele_resname, sele_strandid)

# %%
lw = 2
x = range(1, plot_agent.g_agent.n_node+1)
lbfz = 16
tkfz = 12

fig, ax = plt.subplots(figsize=(8,4))
ax.vlines(x, 0, filter_given, colors='cyan', lw=lw)
ax.set_ylim(0,1)
ax.set_xticks(x[::50])
ax.set_xlabel("Atom Index", fontsize=lbfz)
ax.set_ylabel(r"$\vec{v}_{\mathrm{filter}}$", fontsize=lbfz)
title = r'$|\vec{v}_{\mathrm{filter}}|=1$'
ax.set_title(title, fontsize=lbfz)
ax.tick_params(axis='both', labelsize=tkfz)
plt.tight_layout()
#plt.savefig('filter_example.svg')
plt.show()
