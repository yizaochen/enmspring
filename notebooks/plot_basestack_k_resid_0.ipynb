# %%
import matplotlib.pyplot as plt
from enmspring.basestack_k import StackResidPlot

# %%
host = 'atat_21mer'
s_agent = StackResidPlot(host)

# %%
scaling = 2
figsize = (1.55 * scaling, 1.75* scaling)
fig, d_axes = s_agent.plot_two_strands(figsize)
#plt.tight_layout()
plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{host}_stack_resids.svg', dpi=300, transparent=False)
plt.show()

# %%
figsize = (1.55, 1.75)
fig, d_axes = s_agent.plot_two_strands(figsize)
#plt.tight_layout()
plt.savefig(f'/home/yizaochen/Desktop/drawzone_temp/{host}_stack_resids.svg', dpi=300, transparent=False)
plt.show()

# %%
1.55 *2
