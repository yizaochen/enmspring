# %%
import matplotlib.pyplot as plt
from enmspring.correlation_window import BigScatterv1
bigtraj_folder = '/home/ytcdata/bigtraj_fluctmatch'
corr_folder = '/home/yizaochen/Documents/dna_2021_drawzone/correlation_1'

# %% [markdown]
# ### Part 1: Initialize

# %%
plot_agent = BigScatterv1(bigtraj_folder, corr_folder)
# Out:
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_STRAND1_basestack.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_STRAND2_basestack.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_STRAND1_backbone.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_STRAND2_backbone.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_STRAND1_basestack.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_STRAND2_basestack.csv
# ...

# %% [markdown]
# ### Part 2: Big Scatter Plot

# %%
figsize = (24, 6)
s = 50
centroid = True
fig, axes = plot_agent.scatter_main(figsize, s, centroid)
plt.tight_layout()
plt.savefig('/home/yizaochen/Desktop/drawzone_temp/scatter.png', dpi=150, transparent=False)
plt.show()

# %% [markdown]
# ### Part 3: Raw Scatter

# %%
figsize = (24, 6)
s = 3
fig, axes = plot_agent.scatter_main(figsize, s)
plt.tight_layout()
plt.savefig('/home/yizaochen/Desktop/drawzone_temp/scatter_full.png', dpi=150, transparent=False)
plt.show()
