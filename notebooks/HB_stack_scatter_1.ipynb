# %%
from enmspring.hb_st_scatter import Scatterv0
import matplotlib.pyplot as plt
bigtraj_folder = '/home/ytcdata/bigtraj_fluctmatch'
corr_folder = '/home/yizaochen/Documents/dna_2021_drawzone/correlation_1'

# %% [markdown]
# ### Part 1: Scatter

# %%
plot_agent = Scatterv0(bigtraj_folder, corr_folder)
# Out:
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/atat_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/gcgc_21mer_hb.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_basestack_whole.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/g_tract_21mer_basestack_whole.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/atat_21mer_basestack_whole.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/gcgc_21mer_basestack_whole.csv
# read df from /home/yizaochen/Documents/dna_2021_drawzone/correlation_1/input/a_tract_21mer_backbone_whole.csv
# ...

# %%
figsize = (3.3, 4)
s = 4
plot_agent.scatter_main_2d(figsize, s)
plt.tight_layout()
plt.savefig('/home/yizaochen/Desktop/drawzone_temp/hb_bb_st_scatter.png', dpi=500, transparent=False)
plt.show()

# %%
figsize = (8, 4)
s = 10
plot_agent.scatter_main_3d(figsize, s)
plt.show()
